# %%
import torch

#Scalar(0-D)
scalar = torch.tensor(7)
print(scalar, scalar.ndim, scalar.shape)

#Vector(1-D)
vector = torch.tensor([1, 2, 3])
print(vector, vector.ndim, vector.shape)

#Matrix(2-D)
matrix = torch.tensor([1,2], [3,4])
print(matrix, matrix.ndim, matrix.shape)
# Out:
# /Users/nitishjohnrawat/Desktop/AI-Agentic-Modal-Collaborative-/Collabe-work/PyTorch_Engine/.venv/lib/python3.13/site-packages/torch/_subclasses/functional_tensor.py:368: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# tensor(7) 0 torch.Size([])
# tensor([1, 2, 3]) 1 torch.Size([3])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       8 vector = torch.tensor([1, 2, 3])
#       9 print(vector, vector.ndim, vector.shape)
#      10
#      11 #Matrix(2-D)
# ---> 12 matrix = torch.tensor([1,2], [3,4])
#      13 print(matrix, matrix.ndim, matrix.shape)
#
# TypeError: tensor() takes 1 positional argument but 2 were given
